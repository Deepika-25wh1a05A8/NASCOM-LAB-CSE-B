# %% [markdown]
# basic try except program:

# %%
try:
  n = int(input("enter a number:"))
  print("you entered:",x)
except ValueError:
  print("value is invalid")
# Out:
# enter a number:dws
# value is invalid

# %% [markdown]
# try except else finally program:

# %%
try:
    num = int(input("Enter a number to divide 100: "))
    result = 100 / num
except ZeroDivisionError:
    print("Cannot divide by zero!")
except ValueError:
    print("Invalid input! Not a number.")
else:
    print("Result is:", result)
finally:
    print("Execution complete. This block always runs.")
# Out:
# Enter a number to divide 100: 54
# Result is: 1.8518518518518519
# Execution complete. This block always runs.

# %% [markdown]
# catching multiple exceptions:

# %%
try:
    a = int(10)     # Causes ValueError
    b = 10 / 0      # Causes ZeroDivisionError
except (ValueError, ZeroDivisionError) as e:
    print("An error occurred:", e)
# Out:
# An error occurred: division by zero

# %% [markdown]
# raising custom exceptions:

# %%
def check_age(age):
    if age < 0:
        raise ValueError("Age cannot be negative!")
    else:
        print("Age is valid.")

try:
    check_age(-5)
except ValueError as e:
    print("Caught an exception:", e)
# Out:
# Caught an exception: Age cannot be negative!

# %% [markdown]
# debugging pracices:

# %%
def divide(a,b):
  print(f"dividing {a} by {b}")
  return a / b
print(divide(10,5))
# Out:
# dividing 10 by 5
# 2.0

# %% [markdown]
# using traceback module:

# %%
import traceback

try:
    result = 10 / 0
except Exception as e:
    print("Something went wrong.")
    traceback.print_exc()  # Prints detailed error stack
# Out:
# Something went wrong.
# Traceback (most recent call last):
#   File "/tmp/ipykernel_1339/1155219331.py", line 4, in <cell line: 0>
#     result = 10 / 0
#              ~~~^~~
# ZeroDivisionError: division by zero

# %% [markdown]
# using python debugger:

# %%
def calculate_total(price, quantity):
    # pdb.set_trace()  # Start interactive debugger here
    return price * quantity

print(calculate_total(50, 2))
# Out:
# 100

# %%
from collections import namedtuple
contact = namedtuple("point",'name phone city')
p =point("deepika,1234567893,hyd")
print("detail:",p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1339/325228329.py in <cell line: 0>()
#       1 from collections import namedtuple
#       2 contact = namedtuple("point",'name phone city')
# ----> 3 p =point("deepika,1234567893,hyd")
#       4 print("detail:",p)
#
# NameError: name 'point' is not defined
