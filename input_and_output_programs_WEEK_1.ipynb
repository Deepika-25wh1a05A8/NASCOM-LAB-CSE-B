# %% [markdown]
# input and output format functions

# %%
print("i am deepika")
# Out:
# i am deepika

# %% [markdown]
# fstring :

# %%
name = "deepika"
print(f"student name:{name}")
# Out:
# student name:deepika

# %% [markdown]
# format:

# %%
name = "deepika"
print("Student name:{}".format(name))
# Out:
# Student name:deepika

# %% [markdown]
# % formatting:

# %%
name = "deepika"
print("student name:%s"%name)
# Out:
# student name:deepika

# %% [markdown]
# ASSESSMENT:
# Q1. Write the output.
# print(&quot;Welcome to Python&quot;)
# Output: ________________________________
#
# Q2. Write the output.
# print(25)
# print(50)
# Output: ________________________________
#
# Q3. Write the output.
# name = &quot;Rahul&quot;
# print(name)
# Output: ________________________________
#
# Q4. Write the output.
# a = 15
# b = 10
# print()
# Output: ________________________________
#
# Q5. Write the output.
# a = 20
# b = 4
# print()
# print()
# Output: ________________________________
#
# Q6. Write the output.
# a = 20
# b = 3
#
# print ()
# Output: ________________________________
#
# Q7. Write the output.
# name = &quot;Anjali&quot;
# age = 19
#
# Output: ________________________________
#
# Q8. Write the output with f string
# name = &quot;Priya&quot;
#
# Output: ________________________________
#
# Q9. Write the output with formar
# city = &quot;Hyderabad&quot;
#
# Output: ________________________________
#
# Q10. Write the output % formar
# name = &quot;Kiran&quot;
#
# Output: ________________________________
#
# Q11. Write the output.
# a = 5
# b = 4
#
# Output: ________________________________
#
# Q12. Write the output.
# x = 2
# print()
# Output: ________________________________
#
# Q13. Write the output.
# num = 25
# print()
# Output: ________________________________
#
# Q14. Write the float output with with 2 precision values
# value = 15.522222
# print(type(value))
# Output: ________________________________
#
# Q15. Write the output with f string
# name = &quot;Asha&quot;
# marks = 92
#
# Output: ________________________________
#
# Q16. Write the output.
# print(&quot;Python&quot;, &quot;Programming&quot;, &quot;Language&quot;)
# Output: ________________________________
#
# Q17. Write the output.
# a = 10
# b = 20
# print(&quot;Sum =&quot;, a + b)
# Output: ________________________________
#
# Q18. Write the output.
# name = &quot;Rahul&quot;
# print(name * 3)
# Output: ________________________________
#
# Q19. Write the output.
# age = input(&quot;Enter Age: &quot;)
#
# Output: ________________________________
#
# Q20. Write the output with fstring
# x = 10
# y = 20
#
# Output: ________________________________
#
# Q21. Write the output.
# name = &quot;Amit&quot;
# cgpa = 8.75
#
# Output: ________________________________

# %%
print("Welcome to Python")
# Out:
# Welcome to Python

# %%
print(25)
print(50)
# Out:
# 25
# 50

# %%
a=15
b=10
print(a,b)
# Out:
# 15 10

# %%
a=20
b=4
print(a,b)
# Out:
# 20 4

# %%
name = "Rahul"
print(name)
# Out:
# Rahul

# %%
a=20
b=3
print(a,b)
# Out:
# 20 3

# %%
name = "Anjali"
age = 19
print(name,"is",age,"years old")
# Out:
# Anjali is 19 years old

# %%
name = "priya"
print(f"my name:{name}")
# Out:
# my name:priya

# %%
city = "Hyderabad"
print("my native is {}".format(city))
# Out:
# my native is Hyderabad

# %%
name = "Kiran"
print("my name is %s"%name)
# Out:
# my name is Kiran

# %%
a=5
b=4
print(a+b)
# Out:
# 9

# %%
x=2
print(x)
# Out:
# 2

# %%
num = 25
print(num)
# Out:
# 25

# %%
value = 15.22222
print("value is %.2f"%value)
# Out:
# value is 15.22

# %%
name = "Asha"
marks = 92
print(f"student name:{name}")
print(f"marks:{marks}")
# Out:
# student name:Asha
# marks:92

# %%
print("python","programming","language")
# Out:
# python programming language

# %%
a = 10
b = 20
print("sum =",a+b)
# Out:
# sum = 30

# %%
name = "Rahul"
print(name  * 3)
# Out:
# RahulRahulRahul

# %%
age = input("enter age:")
print(age)
# Out:
# enter age:16

# %%
x = 10
y = 20
print(f"x is{x}")
print(f"y is{y}")

# %%
name  = "Amit"
cgpa = 8.75
print(name,cgpa)

# %% [markdown]
# # 🔹 1. DEFINING A BASIC FUNCTION
#
# # A function is a block of code that performs a task and can be reused.
#
# def greet():
#     print("Hello! Welcome to Python Functions.")
#
# # Calling the function
# greet()
# 🔹 2. FUNCTION WITH PARAMETERS
#
# def greet_user(name):
#     print(f"Hello, {name}!")
#
# greet_user("Alice")
# greet_user("Bob")  # You can reuse the function with different arguments
# 🔹 3. FUNCTION WITH DEFAULT PARAMETERS
#
# def greet_user(name="Guest"):
#     print(f"Welcome, {name}!")
#
# greet_user()         # Uses default
# greet_user("Ravi")   # Overrides default
#  5. USING *args (VARIABLE NUMBER OF POSITIONAL ARGUMENTS)
#
# # *args lets you pass any number of positional arguments as a tuple
#
# def print_names(*names):
#     print("Names passed:", names)
#     for name in names:
#         print("Hello", name)
#
# print_names("Alice", "bob", "Charlie")
# 🔹 6. USING **kwargs (VARIABLE NUMBER OF KEYWORD ARGUMENTS)
#
# # **kwargs lets you pass any number of keyword arguments as a dictionary
#
# def print_info(**info):
#     print("User Info:")
#     for key, value in info.items():
#         print(f"{key} = {value}")
#
# print_info(name="Alice", age=25, city="Delhi")
#  7. COMBINING *args AND **kwargs
#
# def show_details(*args, **kwargs):
#     print("Args:", args)
#     print("Kwargs:", kwargs)
#
# show_details(1, 2, 3, name="Ravi", city="Mumbai")
#  8. FUNCTION NESTING (CALL ONE FUNCTION INSIDE ANOTHER)
#
# def multiply(a, b):
#     return a * b
#
# def square(n):
#     return multiply(n, n)
#
# print("Square of 4:", square(4))

# %%
def greet():
  print("Hello! Welcome to Python functions")
greet()

# %%
def greet_user(name):
  print("Hello",name)
greet_user("Alice")
greet_user("Bob")

# %%
def greet_user(name="Guest"):
    print(f"Welcome, {name}!")

greet_user()
greet_user("Ravi")

# %%
def print_names(*names):
  print("names passed:",names)
  for name in names:
    print("hello",name)
print_names("Alice","Bob","charlie")

# %%
def print_info(**info):
  print("user info:")
  for key, value in info.items():
    print(f"{key} = {value}")
print_info(name="Alice",age = 25 ,city= "delhi")

# %%
def show_details(*args, **kwargs):
    print("Args:", args)
    print("Kwargs:", kwargs)

show_details(1, 2, 3, name="Ravi", city="Mumbai")

# %%
def multiply(a, b):
    return a * b

def square(n):
    return multiply(n, n)

print("Square of 4:", square(4))

# %%
def student_info(**info):
  print("student details")
  for key,value in info.items():
    print(f"{key}={value}")
student_info(name="x",branch="cse")
student_info(name="y",branch="cse")

# %%
from functools import reduce
numbers=list(map(int,input("enter the numbers:").split()))
squared=list(map(lambda x:x**2,numbers))
even_numbers=list(filter(lambda x:x%2==0,squared))
print(f"even_numbers:{even_numbers}")
sum =reduce (lambda x,y:x+y,even_numbers)
print(f"sum of even numbers:{sum}")

# %% [markdown]
#  🔹 1. LISTS
# # A list is an ordered, mutable collection that allows duplicates
#
# fruits = ['apple', 'banana', 'cherry', 'apple']
# print("Original list:", fruits)
#
# # Accessing elements by index
# print("First fruit:", fruits[0])
#
#
# # Adding an item
# fruits.append('orange')
# print("After appending:", fruits)
#
# # Removing an item
# fruits.remove('banana')
# print("After removing banana:", fruits)
#
# # List length
# print("Number of fruits:", len(fruits))# 🔹 2. TUPLES
# # A tuple is an ordered, immutable collection that allows duplicates
#
# dimensions = (10, 20, 30)
# print("Tuple:", dimensions)
#  Accessing elements
# print("Second element:", dimensions[1])
#
# # Tuples are immutable: can't add/remove
# # dimensions[1] = 50 → This would raise an error 🔹 3. SETS
# # A set is an unordered, mutable collection with NO duplicates
#
# unique_numbers = {1, 2, 3, 2, 1}
# print("Set (no duplicates):", unique_numbers)
# # Adding elements
# unique_numbers.add(4)
# print("After adding 4:", unique_numbers)
#
#  Removing elements
# unique_numbers.remove(2)
# print("After removing 2:", unique_numbers)
#
#  Set operations
# set_a = {1, 2, 3}
# set_b = {3, 4, 5}
# print("Union:", set_a | set_b)
# print("Intersection:", set_a & set_b)
# print("Difference (A - B):", set_a - set_b) 4. DICTIONARIES
# # A dictionary stores key-value pairs (like a map or JSON object)
#
# student = {
#     'name': 'Alice',
#     'age': 21,
#     'course': 'Python'
# }
# print("Dictionary:", student)
#  Access value by key
# print("Student name:", student['name'])
#
#  Add or update value
# student['grade'] = 'A'
# print("After adding grade:", student)
#
# # Remove a key
# del student['age']
# print("After deleting age:", student)
#
# # Loop through dictionary
# for key, value in student.items():
#     print(f"{key}: {value}")Bonus: Dictionary from two lists using zip()
# keys = ['id', 'name', 'marks']
# values = [101, 'John', 88]
# student_info = dict(zip(keys, values))
# print("Student Info from zip:", student_info)

# %%
fruits = ['apple', 'banana', 'cherry', 'apple']
print("Original list:", fruits)

# Accessing elements by index
print("First fruit:", fruits[0])

# %%
fruits.append('orange')
print("After appending:", fruits)
